# %%
# !pip install spotipy python-dotenv
import os
import openai
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
# Out:
# Requirement already satisfied: spotipy in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (2.25.1)
# Requirement already satisfied: python-dotenv in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (1.1.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from spotipy) (7.0.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from spotipy) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chock\miniconda3\envs\is5126\lib\site-packages (from requests>=2.25.0->spotipy) (2025.8.3)

# %%
load_dotenv("temp.env")  # loads .env

client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

results = spotify.search(q="track:Blinding Lights artist:The Weeknd", type="track", limit=1)
print(results["tracks"]["items"][0]["external_urls"]["spotify"])
# Out:
# https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Example chat call
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Write a short description of the song 'Blinding Lights' by The Weeknd."}
    ],
    temperature=0
)

# The assistant reply
content = response.choices[0].message.content
print(content)
# Out:
# "Blinding Lights" by The Weeknd is an upbeat synth-pop track that blends 1980s-inspired melodies with modern production. The song features a pulsating rhythm and catchy hooks, capturing themes of longing and desire. Lyrically, it expresses a yearning for connection and the feeling of being lost without a loved one. The vibrant instrumentation and infectious chorus contribute to its anthemic quality, making it a standout hit that resonates with listeners. Released in 2019, "Blinding Lights" became a global sensation, topping charts and earning critical acclaim for its nostalgic yet contemporary sound.

# %%
# Load environment variables
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
SPOTIFY_CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
SPOTIFY_CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")

# Setup clients
client = OpenAI(api_key=OPENAI_API_KEY)
spotify = spotipy.Spotify(auth_manager=SpotifyClientCredentials(
    client_id=SPOTIFY_CLIENT_ID,
    client_secret=SPOTIFY_CLIENT_SECRET
))

def parse_song_input(text: str):
    """
    Extract song title and artist using OpenAI.
    title=None if missing.
    """
    prompt = f"""
    Extract the song title and artist from this text.
    Respond ONLY as JSON with fields "title" and "artist".
    If no song mentioned, set title to null.

    Text: "{text}"
    """
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )
    content = response.choices[0].message.content.strip()

    # Strip markdown fences if any
    if content.startswith("```"):
        content = content.strip("`").replace("json", "").strip()
        if content.endswith("```"):
            content = content[:-3].strip()

    import json
    return json.loads(content)

def search_spotify_song(title: str, artist: str):
    """Search a song by title + artist on Spotify"""
    query = f"track:{title} artist:{artist}"
    results = spotify.search(q=query, type="track", limit=1)
    items = results.get("tracks", {}).get("items", [])
    if not items:
        return None
    track = items[0]
    return {
        "name": track["name"],
        "artist": ", ".join([a["name"] for a in track["artists"]]),
        "album": track["album"]["name"],
        "release_date": track["album"]["release_date"],
        "spotify_url": track["external_urls"]["spotify"],
        "preview_url": track.get("preview_url"),
        "artist_id": track["artists"][0]["id"]
    }

def latest_songs_by_artist(artist: str, limit=5):
    """Get latest songs by artist from Spotify"""
    results = spotify.search(q=f"artist:{artist}", type="track", limit=50)
    tracks = results.get("tracks", {}).get("items", [])
    tracks_sorted = sorted(tracks, key=lambda t: t['album']['release_date'], reverse=True)
    latest = []
    seen_titles = set()
    for t in tracks_sorted:
        if t['name'] in seen_titles:
            continue
        seen_titles.add(t['name'])
        latest.append({
            "name": t["name"],
            "artist": ", ".join([a["name"] for a in t["artists"]]),
            "album": t["album"]["name"],
            "release_date": t["album"]["release_date"],
            "spotify_url": t["external_urls"]["spotify"],
            "preview_url": t.get("preview_url")
        })
        if len(latest) >= limit:
            break
    return latest

def get_artist_description(artist_id):
    """Fetch artist info from Spotify and summarize via OpenAI"""
    artist = spotify.artist(artist_id)
    bio_prompt = f"Give a short description of the artist {artist['name']} based on this info: {artist.get('genres', [])}."
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": bio_prompt}],
        temperature=0
    )
    return response.choices[0].message.content.strip()

def get_song_description(song_name, artist_name):
    """Generate brief song description via OpenAI"""
    prompt = f"Write a short description of the song '{song_name}' by {artist_name}."
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )
    return response.choices[0].message.content.strip()

if __name__ == "__main__":
    user_input = input("Enter song + artist text (or just artist): ")
    try:
        song_info = parse_song_input(user_input)
        print("Parsed input:", song_info)

        if song_info["title"]:
            track = search_spotify_song(song_info["title"], song_info["artist"])
            if track:
                # Add descriptions
                track["artist_description"] = get_artist_description(track["artist_id"])
                track["song_description"] = get_song_description(track["name"], track["artist"])

                print("\n✅ Track info with descriptions:")
                for k, v in track.items():
                    if k != "artist_id":
                        print(f"{k}: {v}")
            else:
                print("⚠️ Track not found on Spotify.")
        else:
            print(f"\nℹ️ No song specified. Showing latest songs by {song_info['artist']}:")
            latest = latest_songs_by_artist(song_info["artist"], limit=5)
            for i, t in enumerate(latest, 1):
                print(f"\n{i}. {t['name']} ({t['release_date']}) - {t['spotify_url']}")
    except Exception as e:
        print("Error:", e)
# Out:
# Enter song + artist text (or just artist):  Play Blinding Lights by The Weeknd
# Parsed input: {'title': 'Blinding Lights', 'artist': 'The Weeknd'}
#
# ✅ Track info with descriptions:
# name: Blinding Lights
# artist: The Weeknd
# album: After Hours
# release_date: 2020-03-20
# spotify_url: https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b
# preview_url: None
# artist_description: The Weeknd, whose real name is Abel Tesfaye, is a Canadian singer, songwriter, and record producer known for his unique blend of R&B, pop, and hip-hop. He gained widespread recognition for his atmospheric sound, introspective lyrics, and distinctive falsetto voice. Emerging from the Toronto music scene in the early 2010s, he first gained attention with his mixtapes, which showcased his innovative approach to music and storytelling. The Weeknd has since released several critically acclaimed albums, earning numerous awards, including Grammy Awards, and has become a prominent figure in contemporary music, known for hits like "Blinding Lights," "Starboy," and "The Hills." His artistic persona often explores themes of love, heartbreak, and the darker sides of fame.
# song_description: "Blinding Lights" by The Weeknd is an upbeat synth-pop track that blends 1980s-inspired melodies with modern production. The song features a pulsating rhythm and catchy hooks, capturing themes of longing and desire. Lyrically, it explores the feelings of loneliness and the search for connection, with the narrator yearning for a loved one to illuminate their life. Its infectious energy and nostalgic sound have made it a global hit, resonating with listeners and earning critical acclaim. The song's vibrant production and emotional depth contribute to its status as one of The Weeknd's signature tracks.
